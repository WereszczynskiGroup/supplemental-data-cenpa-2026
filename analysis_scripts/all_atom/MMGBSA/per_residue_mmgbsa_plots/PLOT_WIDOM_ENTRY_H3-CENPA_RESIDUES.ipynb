# %%
import pandas as pd
import re
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- tail_no_latch ---
filename1 = "H3/run1/DNA+entrytail_no_latch/gbsa_H3_1entry.txt"
filename2 = "H3/run2/DNA+entrytail_no_latch/gbsa_H3_2entry.txt"
filename3 = "H3/run3/DNA+entrytail_no_latch/gbsa_H3_3entry.txt"
filename4 = "H3/run4/DNA+entrytail_no_latch/gbsa_H3_4entry.txt"

f1 = "cenpa/run1/DNA+entrytail_no_latch/gbsa_cenpa_1entry.txt"
f2 = "cenpa/run2/DNA+entrytail_no_latch/gbsa_cenpa_2entry.txt"
f3 = "cenpa/run3/DNA+entrytail_no_latch/gbsa_cenpa_3entry.txt"
f4 = "cenpa/run4/DNA+entrytail_no_latch/gbsa_cenpa_4entry.txt"

# --- latch ---
filename1_l = "H3/run1/DNA+entrylatch/gbsa_H3_1entry.txt"
filename2_l = "H3/run2/DNA+entrylatch/gbsa_H3_2entry.txt"
filename3_l = "H3/run3/DNA+entrylatch/gbsa_H3_3entry.txt"
filename4_l = "H3/run4/DNA+entrylatch/gbsa_H3_4entry.txt"

f1_l = "cenpa/run1/DNA+entrylatch/gbsa_cenpa_1entry.txt"
f2_l = "cenpa/run2/DNA+entrylatch/gbsa_cenpa_2entry.txt"
f3_l = "cenpa/run3/DNA+entrylatch/gbsa_cenpa_3entry.txt"
f4_l = "cenpa/run4/DNA+entrylatch/gbsa_cenpa_4entry.txt"

# --- aN helix ---
filename1_a = "H3/run1/DNA+entryaNhelix/gbsa_H3_1entry.txt"
filename2_a = "H3/run2/DNA+entryaNhelix/gbsa_H3_2entry.txt"
filename3_a = "H3/run3/DNA+entryaNhelix/gbsa_H3_3entry.txt"
filename4_a = "H3/run4/DNA+entryaNhelix/gbsa_H3_4entry.txt"

f1_a = "cenpa/run1/DNA+entryaNhelix/gbsa_cenpa_1entry.txt"
f2_a = "cenpa/run2/DNA+entryaNhelix/gbsa_cenpa_2entry.txt"
f3_a = "cenpa/run3/DNA+entryaNhelix/gbsa_cenpa_3entry.txt"
f4_a = "cenpa/run4/DNA+entryaNhelix/gbsa_cenpa_4entry.txt"


# Pattern: match any line that has 6 columns with "value +/- error"
value_pattern = re.compile(r"([-\d.Ee]+)\s+\+/-\s+([-\d.Ee]+)")

data1, data2, data3, data4 = [], [], [], []
d1, d2, d3, d4 = [], [], [] ,[]

data1_l, data2_l, data3_l, data4_l = [], [], [], []
d1_l, d2_l, d3_l, d4_l = [], [], [], []

data1_a, data2_a, data3_a, data4_a = [], [], [], []
d1_a, d2_a, d3_a, d4_a = [], [], [], []

failures = []

with open(filename1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

# Define column headers
columns = [
    "Residue",
    "Internal", "Internal_err",
    "VDW", "VDW_err",
    "Electrostatic", "Electrostatic_err",
    "Polar", "Polar_err",
    "NonPolar", "NonPolar_err",
    "Total", "Total_err"
]

df1 = pd.DataFrame(data1, columns=columns)
df2 = pd.DataFrame(data2, columns=columns)
df3 = pd.DataFrame(data3, columns=columns)
df4 = pd.DataFrame(data4, columns=columns)

df5 = pd.DataFrame(d1, columns=columns)
df6 = pd.DataFrame(d2, columns=columns)
df7 = pd.DataFrame(d3, columns=columns)
df8 = pd.DataFrame(d4, columns=columns)

df1_l = pd.DataFrame(data1_l, columns=columns)
df2_l = pd.DataFrame(data2_l, columns=columns)
df3_l = pd.DataFrame(data3_l, columns=columns)
df4_l = pd.DataFrame(data4_l, columns=columns)

df5_l = pd.DataFrame(d1_l, columns=columns)
df6_l = pd.DataFrame(d2_l, columns=columns)
df7_l = pd.DataFrame(d3_l, columns=columns)
df8_l = pd.DataFrame(d4_l, columns=columns)

df1_a = pd.DataFrame(data1_a, columns=columns)
df2_a = pd.DataFrame(data2_a, columns=columns)
df3_a = pd.DataFrame(data3_a, columns=columns)
df4_a = pd.DataFrame(data4_a, columns=columns)

df5_a = pd.DataFrame(d1_a, columns=columns)
df6_a = pd.DataFrame(d2_a, columns=columns)
df7_a = pd.DataFrame(d3_a, columns=columns)
df8_a = pd.DataFrame(d4_a, columns=columns)

# ✅ Summary
print(f"✅ Parsed {len(df1)} residues.")
print(df1.head())

# Optional debug
if failures:
    print(f"\n⚠️ Skipped {len(failures)} lines. First 5:")
    for f in failures[:5]:
        print(f)
# Out:
# ✅ Parsed 330 residues.
#   Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0    DA51       0.0           0.0 -0.005    0.006        -17.707
# 1     DT2       0.0           0.0 -0.010    0.015        -61.646
# 2     DC3       0.0           0.0 -0.033    0.064        -71.181
# 3     DG4       0.0           0.0 -0.231    0.541        -77.237
# 4     DA5       0.0           0.0 -0.457    0.681        -99.299
#
#    Electrostatic_err   Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0              2.043  17.698      2.040     0.000         0.000 -0.015
# 1              8.763  61.610      8.753    -0.000         0.000 -0.047
# 2             13.326  71.062     13.224    -0.001         0.006 -0.153
# 3             17.794  77.092     17.600    -0.038         0.112 -0.415
# 4             20.783  99.038     20.414    -0.095         0.159 -0.814
#
#    Total_err
# 0      0.016
# 1      0.030
# 2      0.339
# 3      1.110
# 4      1.186
#
# ⚠️ Skipped 72 lines. First 5:
# Wrong # of value/error pairs: | Run on Sat Jan 17 19:51:18 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2
# Wrong # of value/error pairs: Residue |  Location |       Internal      |    van der Waals    |    Electrostatic    |   Polar Solvation   |    Non-Polar Solv.  |       TOTAL
# Wrong # of value/error pairs: | Run on Sat Jan 17 22:24:44 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2

# %%
df6
# Out:
#     Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0      DA51       0.0           0.0 -0.001    0.002        -10.181
# 1       DT2       0.0           0.0 -0.001    0.002        -34.377
# 2       DC3       0.0           0.0 -0.002    0.006        -38.103
# 3       DG4       0.0           0.0 -0.007    0.037        -39.954
# 4       DA5       0.0           0.0 -0.025    0.159        -47.764
# ..      ...       ...           ...    ...      ...            ...
# 324  SER325       0.0           0.0 -0.168    0.317          3.806
# 325  LEU326       0.0           0.0 -0.353    0.561          0.187
# 326  GLY327       0.0           0.0 -0.425    0.645         -1.122
# 327  ALA328       0.0           0.0 -0.514    0.727         -0.195
# 328  SER329       0.0           0.0 -0.858    1.124         -3.156
#
#      Electrostatic_err   Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0                1.021  10.179      1.021     0.000         0.000 -0.003
# 1                3.207  34.369      3.202     0.000         0.000 -0.009
# 2                4.132  38.090      4.125     0.000         0.000 -0.015
# 3                4.305  39.943      4.305    -0.000         0.008 -0.018
# 4                5.849  47.750      5.876    -0.003         0.032 -0.042
# ..                 ...     ...        ...       ...           ...    ...
# 324              6.436  -3.559      6.265    -0.022         0.074  0.056
# 325              6.307   0.145      6.060    -0.053         0.112 -0.075
# 326              7.402   1.678      7.239    -0.075         0.137  0.057
# 327              7.156   0.478      7.293    -0.072         0.141 -0.303
# 328             10.242   3.884      9.956    -0.210         0.256 -0.340
#
#      Total_err
# 0        0.003
# 1        0.006
# 2        0.011
# 3        0.030
# 4        0.099
# ..         ...
# 324      0.659
# 325      0.531
# 326      0.486
# 327      0.624
# 328      1.146
#
# [329 rows x 13 columns]

# %%
# Ensure each df has a numeric residue ID column
for df in [df1, df2, df3, df4]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs = []
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs.append(subset)

# Merge on Residue
merged = dfs[0]
for df in dfs[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   ALA295     2.53225              2.246669
# 1   ARG296    -2.71500              1.012037
# 2   THR297    -0.58575              0.893389
# 3   LYS298     0.70525              1.154567
# 4   GLN299    -0.16725              0.391157
# 5   THR300    -0.09500              0.407650
# 6   ALA301    -0.27925              0.263943
# 7   ARG302    -1.43550              0.852845
# 8   LYS303     0.47075              1.461166
# 9   SER304    -0.56325              0.593842
# 10  THR305    -1.70750              1.077101
# 11  GLY306    -0.28300              0.297947
# 12  GLY307    -0.02875              0.174993
# 13  LYS308    -0.07825              0.835361
# 14  ALA309     0.00775              0.088916
# 15  PRO310    -0.24825              0.257502
# 16  ARG311    -1.10450              0.726632
# 17  LYS312     0.70700              1.465769
# 18  GLN313    -0.30625              0.396502
# 19  LEU314    -0.11975              0.254842
# 20  ALA315    -0.23950              0.304185
# 21  THR316    -0.29150              0.562031
# 22  LYS317     0.13925              1.753578
# 23  ALA318    -0.28025              0.375353
# 24  ALA319    -0.03775              0.194180
# 25  ARG320    -1.06275              0.870178
# 26  LYS321    -0.62375              0.613790
# 27  SER322    -0.15850              0.398521
# 28  ALA323    -0.06875              0.152941
# 29  PRO324    -0.05650              0.270001
# 30  ALA325    -0.22650              0.324388
# 31  THR326    -0.19600              0.389252
# 32  GLY327    -0.12050              0.161777
# 33  GLY328    -0.08300              0.200240
# 34  VAL329    -0.15350              0.348641
# 35  LYS330    -0.87600              1.325376

# %%
# Ensure each df has a numeric residue ID column
for df in [df5, df6, df7, df8]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s = []
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s.append(subset)

# Merge on Residue
merged = df2s[0]
for df in df2s[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2 = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   GLY295     1.65600              1.468826
# 1   PRO296    -0.67675              0.414807
# 2   ARG297    -1.60175              0.973054
# 3   ARG298    -2.16600              0.891917
# 4   ARG299    -0.51200              0.791491
# 5   SER300    -1.01400              0.729459
# 6   ARG301    -1.56350              0.926872
# 7   LYS302    -0.39875              1.314857
# 8   PRO303    -0.42200              0.291117
# 9   GLU304     0.62275              0.240679
# 10  ALA305     0.02450              0.094767
# 11  PRO306    -0.15475              0.310868
# 12  ARG307    -1.39850              0.794130
# 13  ARG308    -1.16550              0.899424
# 14  ARG309    -1.60850              0.884673
# 15  SER310    -0.49250              0.824267
# 16  PRO311    -0.56825              0.461732
# 17  SER312    -0.52650              0.619555
# 18  PRO313    -0.12050              0.202235
# 19  THR314    -0.00775              0.215321
# 20  PRO315    -0.16925              0.266863
# 21  THR316     0.02125              0.248903
# 22  PRO317    -0.23500              0.294234
# 23  GLY318     0.06275              0.169578
# 24  PRO319    -0.71150              0.520983
# 25  SER320    -0.64975              0.770585
# 26  ARG321    -2.48975              1.067421
# 27  ARG322    -2.00150              0.884789
# 28  GLY323     0.08300              0.148075
# 29  PRO324    -0.22075              0.252720
# 30  SER325    -0.10625              0.429223
# 31  LEU326    -0.35450              0.360882
# 32  GLY327    -0.17225              0.298980
# 33  ALA328    -0.59775              0.463644
# 34  SER329    -1.11100              0.830695

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_l, df2_l, df3_l, df4_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_l = []
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_l.append(subset)

# Merge on Residue
merged = dfs_l[0]
for df in dfs_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  PRO295    -0.79225              0.478481
# 1  HIE296    -0.20300              0.432937
# 2  ARG297    -2.25525              1.021914
# 3  TYR298    -3.22075              0.906877
# 4  ARG299    -2.57125              0.784902
# 5  PRO300    -4.75325              0.591174
# 6  GLY301    -1.70475              0.335198

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_l, df6_l, df7_l, df8_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_l = []
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_l.append(subset)

# Merge on Residue
merged = df2s_l[0]
for df in df2s_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  HIE295    -0.37025              0.563118
# 1  GLN296    -0.55450              0.560891
# 2  HIE297    -0.71825              0.692798
# 3  SER298    -0.85150              0.907736
# 4  ARG299    -2.48600              1.178596
# 5  ARG300    -2.82025              0.960241
# 6  ARG301    -2.91350              0.882285

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_a, df2_a, df3_a, df4_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_a = []
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_a.append(subset)

# Merge on Residue
merged = dfs_a[0]
for df in dfs_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  THR295    -0.54925              0.394015
# 1  VAL296    -4.25125              0.481735
# 2  ALA297    -1.80650              0.345414
# 3  LEU298    -0.15975              0.073475
# 4  ARG299    -2.38525              0.725813
# 5  GLU300     1.87700              0.111939
# 6  ILE301    -0.11225              0.014453
# 7  ARG302    -1.56725              0.516020
# 8  ARG303    -1.91375              0.518790
# 9  TYR304     0.05800              0.016789

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_a, df6_a, df7_a, df8_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_a = []
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_a.append(subset)

# Merge on Residue
merged = df2s_a[0]
for df in df2s_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  GLN295    -0.33575              0.441188
# 1  GLY296    -0.10700              0.143727
# 2  TRP297    -1.06825              0.632273
# 3  LEU298    -0.09175              0.034035
# 4  LYS299    -0.63500              1.075511
# 5  GLU300     1.84375              0.209029
# 6  ILE301    -0.07575              0.017894
# 7  ARG302    -1.04450              0.260298
# 8  LYS303    -1.01600              0.246674
# 9  LEU304    -0.05725              0.006031

# %%
avg1 = np.concatenate([
    np.array(result['Total_mean']),
    np.array(result_l['Total_mean']),
    np.array(result_a['Total_mean'])
])

avg2 = np.concatenate([
    np.array(result2['Total_mean']),
    np.array(result2_l['Total_mean']),
    np.array(result2_a['Total_mean'])
])

std = np.concatenate([
    np.array(result['Total_err_propagated']),
    np.array(result_l['Total_err_propagated']),
    np.array(result_a['Total_err_propagated'])
])

std2 = np.concatenate([
    np.array(result2['Total_err_propagated']),
    np.array(result2_l['Total_err_propagated']),
    np.array(result2_a['Total_err_propagated'])
])

ste1 = std / sqrt(4)
ste2 = std2 / sqrt(4)

# %%
width = 0.25

listH3 = ['A1', 'R2', 'T3', 'K4', 'Q5', 'T6', 'A7', 'R8', 'K9', 'S10',
          'T11', 'G12', 'G13', 'K14', 'A15', 'P16', 'R17', 'K18', 'Q19', 'L20',
          'A21', 'T22', 'K23', 'A24', 'A25', 'R26', 'K27', 'S28', 'A29', 'P30',
          'A31', 'T32', 'G33', 'G34', 'V35', 'K36', 'K37', 'P38', 'H39', 'R40',
          'Y41', 'R42', 'P43', 'G44', 'T45', 'V46', 'A47', 'L48', 'R49', 'E50',
          'I51', 'R52', 'R53', 'Y54']

listcenpa = ['G1', 'P2', 'R3', 'R4', 'R5', 'S6', 'R7', 'K8', 'P9', 'E10',
             'A11', 'P12', 'R13', 'R14', 'R15', 'S16', 'P17', 'S18', 'P19', 'T20',
             'P21', 'T22', 'P23', 'G24', 'P25', 'S26', 'R27', 'R28', 'G29', 'P30',
             'S31', 'L32', 'G33', 'A34', 'S35', 'S36', 'H37', 'Q38', 'H39', 'S40',
             'R41', 'R42', 'R43', 'Q44', 'G45', 'W46', 'L47', 'K48', 'E49', 'I50',
             'R51', 'K52', 'L53']

# %%
from matplotlib.patches import Patch
# -----------------------------
# Region-specific colors
# -----------------------------
highlight_h3 = {}

# tails (0–36)
for i in range(0, 37):
    highlight_h3[i] = "tab:blue"

# latch (37–43)
for i in range(37, 44):
    highlight_h3[i] = "tab:blue"

# alphaN (44–53)
for i in range(44, 54):
    highlight_h3[i] = "tab:blue"


highlight_cenpa = {}

# tails (0–35)
for i in range(0, 36):
    highlight_cenpa[i] = "tab:orange"

# latch (36–42)
for i in range(36, 43):
    highlight_cenpa[i] = "tab:orange"

# alphaN (44–52)
for i in range(43, 53):
    highlight_cenpa[i] = "tab:orange"


# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(9, 3))
ax = plt.gca()

# H3 bars
for i in range(len(avg1)):
    plt.bar(
        x_h3[i],
        avg1[i],
        yerr=ste1[i],
        width=width,
        color=highlight_h3[i]
    )

# CENP-A bars
for i in range(len(avg2)):
    plt.bar(
        x_cenpa[i] + width,
        avg2[i],
        yerr=ste2[i],
        width=width,
        color=highlight_cenpa[i]
    )

# baseline
plt.axhline(y=0, color='black')

# separator lines
for xpos in [37.5, 44.5]:
    ax.axvline(x=xpos, linestyle=':', color='black', linewidth=1)

# limits/title
plt.ylim(-5, 10)
plt.title('Entry Tail - DNA Binding Energy')
plt.ylabel('Binding Energy (kcal/mol)')

# -----------------------------
# Bottom axis (CENP-A)
# -----------------------------
ax.set_xticks(x_cenpa + width/2)
ax.set_xticklabels(listcenpa, rotation=90)

for lbl, i in zip(ax.get_xticklabels(), range(len(listcenpa))):
    lbl.set_color(highlight_cenpa[i])

# -----------------------------
# Top axis (H3)
# -----------------------------
ax_top = ax.twiny()

xmin = 0.5
xmax = 54.5 + width

ax.set_xlim(xmin, xmax)
ax_top.set_xlim(xmin, xmax)

ax_top.set_xticks(x_h3)
ax_top.set_xticklabels(listH3, rotation=90)

for lbl, i in zip(ax_top.get_xticklabels(), range(len(listH3))):
    lbl.set_color(highlight_h3[i])

# -----------------------------
# Legend
# -----------------------------
legend_handles = [
    Patch(facecolor='tab:blue', label='H3'),
    Patch(facecolor='tab:orange', label='CENP-A'),
]

ax.legend(handles=legend_handles, loc='upper right', fontsize=8)

plt.tight_layout()

plt.savefig('WIDOM_ENTRY_H3-CENPA_dna_gbsa_byres.pdf')
plt.savefig('WIDOM_ENTRY_H3-CENPA_dna_gbsa_byres.png')

plt.show()
