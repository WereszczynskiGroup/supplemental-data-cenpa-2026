# %%
import pandas as pd
import re
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- tail_no_latch ---
filename1 = "CSH3/run1/DNA+exittail_no_latch/gbsa_CSH3_1exit.txt"
filename2 = "CSH3/run2/DNA+exittail_no_latch/gbsa_CSH3_2exit.txt"
filename3 = "CSH3/run3/DNA+exittail_no_latch/gbsa_CSH3_3exit.txt"
filename4 = "CSH3/run4/DNA+exittail_no_latch/gbsa_CSH3_4exit.txt"

f1 = "CScenpa/run1/DNA+exittail_no_latch/gbsa_CScenpa_1exit.txt"
f2 = "CScenpa/run2/DNA+exittail_no_latch/gbsa_CScenpa_2exit.txt"
f3 = "CScenpa/run3/DNA+exittail_no_latch/gbsa_CScenpa_3exit.txt"
f4 = "CScenpa/run4/DNA+exittail_no_latch/gbsa_CScenpa_4exit.txt"

# --- latch ---
filename1_l = "CSH3/run1/DNA+exitlatch/gbsa_CSH3_1exit.txt"
filename2_l = "CSH3/run2/DNA+exitlatch/gbsa_CSH3_2exit.txt"
filename3_l = "CSH3/run3/DNA+exitlatch/gbsa_CSH3_3exit.txt"
filename4_l = "CSH3/run4/DNA+exitlatch/gbsa_CSH3_4exit.txt"

f1_l = "CScenpa/run1/DNA+exitlatch/gbsa_CScenpa_1exit.txt"
f2_l = "CScenpa/run2/DNA+exitlatch/gbsa_CScenpa_2exit.txt"
f3_l = "CScenpa/run3/DNA+exitlatch/gbsa_CScenpa_3exit.txt"
f4_l = "CScenpa/run4/DNA+exitlatch/gbsa_CScenpa_4exit.txt"

# --- aN helix ---
filename1_a = "CSH3/run1/DNA+exitaNhelix/gbsa_CSH3_1exit.txt"
filename2_a = "CSH3/run2/DNA+exitaNhelix/gbsa_CSH3_2exit.txt"
filename3_a = "CSH3/run3/DNA+exitaNhelix/gbsa_CSH3_3exit.txt"
filename4_a = "CSH3/run4/DNA+exitaNhelix/gbsa_CSH3_4exit.txt"

f1_a = "CScenpa/run1/DNA+exitaNhelix/gbsa_CScenpa_1exit.txt"
f2_a = "CScenpa/run2/DNA+exitaNhelix/gbsa_CScenpa_2exit.txt"
f3_a = "CScenpa/run3/DNA+exitaNhelix/gbsa_CScenpa_3exit.txt"
f4_a = "CScenpa/run4/DNA+exitaNhelix/gbsa_CScenpa_4exit.txt"


# Pattern: match any line that has 6 columns with "value +/- error"
value_pattern = re.compile(r"([-\d.Ee]+)\s+\+/-\s+([-\d.Ee]+)")

data1, data2, data3, data4 = [], [], [], []
d1, d2, d3, d4 = [], [], [] ,[]

data1_l, data2_l, data3_l, data4_l = [], [], [], []
d1_l, d2_l, d3_l, d4_l = [], [], [], []

data1_a, data2_a, data3_a, data4_a = [], [], [], []
d1_a, d2_a, d3_a, d4_a = [], [], [], []

failures = []

with open(filename1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

# Define column headers
columns = [
    "Residue",
    "Internal", "Internal_err",
    "VDW", "VDW_err",
    "Electrostatic", "Electrostatic_err",
    "Polar", "Polar_err",
    "NonPolar", "NonPolar_err",
    "Total", "Total_err"
]

df1 = pd.DataFrame(data1, columns=columns)
df2 = pd.DataFrame(data2, columns=columns)
df3 = pd.DataFrame(data3, columns=columns)
df4 = pd.DataFrame(data4, columns=columns)

df5 = pd.DataFrame(d1, columns=columns)
df6 = pd.DataFrame(d2, columns=columns)
df7 = pd.DataFrame(d3, columns=columns)
df8 = pd.DataFrame(d4, columns=columns)

df1_l = pd.DataFrame(data1_l, columns=columns)
df2_l = pd.DataFrame(data2_l, columns=columns)
df3_l = pd.DataFrame(data3_l, columns=columns)
df4_l = pd.DataFrame(data4_l, columns=columns)

df5_l = pd.DataFrame(d1_l, columns=columns)
df6_l = pd.DataFrame(d2_l, columns=columns)
df7_l = pd.DataFrame(d3_l, columns=columns)
df8_l = pd.DataFrame(d4_l, columns=columns)

df1_a = pd.DataFrame(data1_a, columns=columns)
df2_a = pd.DataFrame(data2_a, columns=columns)
df3_a = pd.DataFrame(data3_a, columns=columns)
df4_a = pd.DataFrame(data4_a, columns=columns)

df5_a = pd.DataFrame(d1_a, columns=columns)
df6_a = pd.DataFrame(d2_a, columns=columns)
df7_a = pd.DataFrame(d3_a, columns=columns)
df8_a = pd.DataFrame(d4_a, columns=columns)

# ✅ Summary
print(f"✅ Parsed {len(df1)} residues.")
print(df1.head())

# Optional debug
if failures:
    print(f"\n⚠️ Skipped {len(failures)} lines. First 5:")
    for f in failures[:5]:
        print(f)
# Out:
# ✅ Parsed 330 residues.
#   Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0    DA51       0.0           0.0 -0.078    0.304        -14.147
# 1     DT2       0.0           0.0 -0.056    0.236        -43.225
# 2     DC3       0.0           0.0 -0.021    0.097        -42.562
# 3     DA4       0.0           0.0 -0.003    0.009        -41.692
# 4     DA5       0.0           0.0 -0.001    0.002        -42.107
#
#    Electrostatic_err   Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0              4.949  14.164      5.003    -0.012         0.055 -0.074
# 1             12.687  43.236     12.741    -0.007         0.032 -0.052
# 2             12.042  42.547     12.025    -0.004         0.021 -0.040
# 3              9.798  41.676      9.780    -0.000         0.000 -0.019
# 4              8.447  42.092      8.434     0.000         0.000 -0.016
#
#    Total_err
# 0      0.268
# 1      0.185
# 2      0.143
# 3      0.028
# 4      0.017
#
# ⚠️ Skipped 72 lines. First 5:
# Wrong # of value/error pairs: | Run on Sun Jan 18 12:49:07 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2
# Wrong # of value/error pairs: Residue |  Location |       Internal      |    van der Waals    |    Electrostatic    |   Polar Solvation   |    Non-Polar Solv.  |       TOTAL
# Wrong # of value/error pairs: | Run on Sun Jan 18 10:18:25 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2

# %%
df6
# Out:
#     Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0      DA51       0.0           0.0 -0.000    0.000         -6.576
# 1       DT2       0.0           0.0 -0.000    0.000        -20.699
# 2       DC3       0.0           0.0 -0.000    0.000        -19.651
# 3       DA4       0.0           0.0 -0.000    0.000        -19.382
# 4       DA5       0.0           0.0 -0.000    0.000        -19.578
# ..      ...       ...           ...    ...      ...            ...
# 324  SER325       0.0           0.0 -0.052    0.049          0.490
# 325  LEU326       0.0           0.0 -0.044    0.050          3.042
# 326  GLY327       0.0           0.0 -0.136    0.191         -3.193
# 327  ALA328       0.0           0.0 -0.776    0.770         -7.728
# 328  SER329       0.0           0.0 -1.312    0.769         -2.010
#
#      Electrostatic_err   Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0                0.367   6.575      0.367     0.000         0.000 -0.000
# 1                1.054  20.699      1.054     0.000         0.000 -0.000
# 2                0.755  19.651      0.755     0.000         0.000 -0.000
# 3                0.620  19.382      0.620     0.000         0.000 -0.000
# 4                0.575  19.578      0.575     0.000         0.000 -0.000
# ..                 ...     ...        ...       ...           ...    ...
# 324              8.584  -0.372      8.560    -0.002         0.011  0.063
# 325              4.980  -2.987      4.957    -0.001         0.008  0.010
# 326              5.227   3.290      5.143    -0.007         0.022 -0.046
# 327              6.165   8.022      5.742    -0.117         0.136 -0.599
# 328             10.005   3.251      9.961    -0.293         0.109 -0.364
#
#      Total_err
# 0        0.001
# 1        0.001
# 2        0.001
# 3        0.001
# 4        0.001
# ..         ...
# 324      0.059
# 325      0.055
# 326      0.304
# 327      0.763
# 328      0.787
#
# [329 rows x 13 columns]

# %%
# Ensure each df has a numeric residue ID column
for df in [df1, df2, df3, df4]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs = []
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs.append(subset)

# Merge on Residue
merged = dfs[0]
for df in dfs[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   ALA295     8.64075              3.662186
# 1   ARG296    -2.74575              1.072894
# 2   THR297    -1.97000              1.097491
# 3   LYS298     1.84750              1.301562
# 4   GLN299    -0.62650              0.611700
# 5   THR300    -0.59000              0.795745
# 6   ALA301    -0.13800              0.326009
# 7   ARG302    -2.10850              0.811860
# 8   LYS303    -1.49100              0.829011
# 9   SER304    -0.81275              0.818961
# 10  THR305    -0.09725              0.359344
# 11  GLY306    -0.18950              0.253506
# 12  GLY307    -0.05100              0.281384
# 13  LYS308     1.18800              1.813371
# 14  ALA309    -0.85675              0.523658
# 15  PRO310    -0.34475              0.316825
# 16  ARG311    -1.07300              0.957148
# 17  LYS312     0.15175              1.703640
# 18  GLN313    -0.33225              0.530354
# 19  LEU314    -0.12125              0.244062
# 20  ALA315    -0.17025              0.263554
# 21  THR316    -0.49550              0.628354
# 22  LYS317     0.48775              1.753706
# 23  ALA318    -0.28350              0.345920
# 24  ALA319    -0.27975              0.274600
# 25  ARG320    -2.22625              0.957304
# 26  LYS321    -0.54875              1.129064
# 27  SER322    -0.92125              0.991939
# 28  ALA323     0.02400              0.225662
# 29  PRO324    -0.38000              0.418837
# 30  ALA325    -0.32275              0.316735
# 31  THR326    -0.20950              0.441651
# 32  GLY327    -0.13925              0.257000
# 33  GLY328     0.01025              0.211290
# 34  VAL329    -0.43200              0.365198
# 35  LYS330    -0.57700              0.998820

# %%
# Ensure each df has a numeric residue ID column
for df in [df5, df6, df7, df8]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s = []
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s.append(subset)

# Merge on Residue
merged = df2s[0]
for df in df2s[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2 = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   GLY295     0.74700              0.891278
# 1   PRO296    -0.56000              0.572164
# 2   ARG297    -2.88525              0.751555
# 3   ARG298    -2.41825              0.971077
# 4   ARG299    -1.15150              0.947762
# 5   SER300    -0.40175              0.575342
# 6   ARG301    -2.30100              0.972634
# 7   LYS302    -1.01225              1.209327
# 8   PRO303    -0.15450              0.195081
# 9   GLU304     0.69650              0.465957
# 10  ALA305    -0.17050              0.272676
# 11  PRO306    -0.15700              0.307854
# 12  ARG307    -0.80650              0.666498
# 13  ARG308    -1.22225              0.744930
# 14  ARG309    -1.33650              0.718223
# 15  SER310    -0.58600              0.783512
# 16  PRO311    -0.02800              0.069430
# 17  SER312     0.03850              0.138959
# 18  PRO313    -0.08625              0.154240
# 19  THR314     0.12250              0.132234
# 20  PRO315    -0.34825              0.278541
# 21  THR316     0.03550              0.212220
# 22  PRO317    -0.72000              0.448887
# 23  GLY318    -0.10375              0.210964
# 24  PRO319     0.04025              0.370587
# 25  SER320    -0.59650              0.505916
# 26  ARG321    -1.91575              1.113735
# 27  ARG322    -1.83125              0.859029
# 28  GLY323     0.09825              0.173827
# 29  PRO324    -0.53575              0.505818
# 30  SER325    -0.37950              0.490980
# 31  LEU326    -0.12725              0.194852
# 32  GLY327    -0.01025              0.163389
# 33  ALA328    -0.28000              0.299694
# 34  SER329    -0.37700              0.465098

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_l, df2_l, df3_l, df4_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_l = []
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_l.append(subset)

# Merge on Residue
merged = dfs_l[0]
for df in dfs_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  PRO295    -0.57750              0.320241
# 1  HIE296     0.35750              0.477058
# 2  ARG297    -1.88675              0.889125
# 3  TYR298    -2.26300              0.603908
# 4  ARG299    -2.92050              0.852189
# 5  PRO300    -3.93550              0.379316
# 6  GLY301    -1.25625              0.207609

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_l, df6_l, df7_l, df8_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_l = []
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_l.append(subset)

# Merge on Residue
merged = df2s_l[0]
for df in df2s_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  HIE295    -0.47975              0.433558
# 1  GLN296    -0.91850              0.576772
# 2  HIE297    -0.57925              0.566360
# 3  SER298    -1.65525              0.856615
# 4  ARG299    -2.76050              1.049448
# 5  ARG300    -3.20550              0.916703
# 6  ARG301    -2.84600              1.009256

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_a, df2_a, df3_a, df4_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_a = []
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_a.append(subset)

# Merge on Residue
merged = dfs_a[0]
for df in dfs_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  THR295    -0.68075              0.395413
# 1  VAL296    -2.99675              0.295415
# 2  ALA297    -1.14250              0.241819
# 3  LEU298    -0.14275              0.042082
# 4  ARG299    -2.53100              0.834177
# 5  GLU300     1.81350              0.096880
# 6  ILE301    -0.09250              0.013677
# 7  ARG302    -1.65950              0.607597
# 8  ARG303    -1.75650              0.481720
# 9  TYR304     0.06550              0.011766

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_a, df6_a, df7_a, df8_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_a = []
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_a.append(subset)

# Merge on Residue
merged = df2s_a[0]
for df in df2s_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  GLN295     0.06000              0.553635
# 1  GLY296    -0.04675              0.094541
# 2  TRP297    -0.85150              0.509126
# 3  LEU298    -0.11375              0.040523
# 4  LYS299    -0.73725              1.000741
# 5  GLU300     1.49850              0.139719
# 6  ILE301    -0.10950              0.030284
# 7  ARG302    -1.07225              0.306626
# 8  LYS303    -1.00100              0.145906
# 9  LEU304    -0.05300              0.005766

# %%
avg1 = np.concatenate([
    np.array(result['Total_mean']),
    np.array(result_l['Total_mean']),
    np.array(result_a['Total_mean'])
])

avg2 = np.concatenate([
    np.array(result2['Total_mean']),
    np.array(result2_l['Total_mean']),
    np.array(result2_a['Total_mean'])
])

std = np.concatenate([
    np.array(result['Total_err_propagated']),
    np.array(result_l['Total_err_propagated']),
    np.array(result_a['Total_err_propagated'])
])

std2 = np.concatenate([
    np.array(result2['Total_err_propagated']),
    np.array(result2_l['Total_err_propagated']),
    np.array(result2_a['Total_err_propagated'])
])

ste1 = std / sqrt(4)
ste2 = std2 / sqrt(4)

# %%
width = 0.25

listH3 = ['A1', 'R2', 'T3', 'K4', 'Q5', 'T6', 'A7', 'R8', 'K9', 'S10',
          'T11', 'G12', 'G13', 'K14', 'A15', 'P16', 'R17', 'K18', 'Q19', 'L20',
          'A21', 'T22', 'K23', 'A24', 'A25', 'R26', 'K27', 'S28', 'A29', 'P30',
          'A31', 'T32', 'G33', 'G34', 'V35', 'K36', 'K37', 'P38', 'H39', 'R40',
          'Y41', 'R42', 'P43', 'G44', 'T45', 'V46', 'A47', 'L48', 'R49', 'E50',
          'I51', 'R52', 'R53', 'Y54']

listcenpa = ['G1', 'P2', 'R3', 'R4', 'R5', 'S6', 'R7', 'K8', 'P9', 'E10',
             'A11', 'P12', 'R13', 'R14', 'R15', 'S16', 'P17', 'S18', 'P19', 'T20',
             'P21', 'T22', 'P23', 'G24', 'P25', 'S26', 'R27', 'R28', 'G29', 'P30',
             'S31', 'L32', 'G33', 'A34', 'S35', 'S36', 'H37', 'Q38', 'H39', 'S40',
             'R41', 'R42', 'R43', 'Q44', 'G45', 'W46', 'L47', 'K48', 'E49', 'I50',
             'R51', 'K52', 'L53']

# %%
from matplotlib.patches import Patch
# -----------------------------
# Region-specific colors
# -----------------------------
highlight_h3 = {}

# tails (0–36)
for i in range(0, 37):
    highlight_h3[i] = "tab:blue"

# latch (37–43)
for i in range(37, 44):
    highlight_h3[i] = "tab:blue"

# alphaN (44–53)
for i in range(44, 54):
    highlight_h3[i] = "tab:blue"


highlight_cenpa = {}

# tails (0–35)
for i in range(0, 36):
    highlight_cenpa[i] = "tab:orange"

# latch (36–42)
for i in range(36, 43):
    highlight_cenpa[i] = "tab:orange"

# alphaN (44–52)
for i in range(43, 53):
    highlight_cenpa[i] = "tab:orange"


# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(9, 3))
ax = plt.gca()

# CSH3 bars
for i in range(len(avg1)):
    plt.bar(
        x_h3[i],
        avg1[i],
        yerr=ste1[i],
        width=width,
        color=highlight_h3[i]
    )

# CSCENP-A bars
for i in range(len(avg2)):
    plt.bar(
        x_cenpa[i] + width,
        avg2[i],
        yerr=ste2[i],
        width=width,
        color=highlight_cenpa[i]
    )

# baseline
plt.axhline(y=0, color='black')

# separator lines
for xpos in [37.5, 44.5]:
    ax.axvline(x=xpos, linestyle=':', color='black', linewidth=1)

# limits/title
plt.ylim(-5, 10)
plt.title('Exit Tail - DNA Binding Energy')
plt.ylabel('Binding Energy (kcal/mol)')

# -----------------------------
# Bottom axis (CSCENP-A)
# -----------------------------
ax.set_xticks(x_cenpa + width/2)
ax.set_xticklabels(listcenpa, rotation=90)

for lbl, i in zip(ax.get_xticklabels(), range(len(listcenpa))):
    lbl.set_color(highlight_cenpa[i])

# -----------------------------
# Top axis (CSH3)
# -----------------------------
ax_top = ax.twiny()

xmin = 0.5
xmax = 54.5 + width

ax.set_xlim(xmin, xmax)
ax_top.set_xlim(xmin, xmax)

ax_top.set_xticks(x_h3)
ax_top.set_xticklabels(listH3, rotation=90)

for lbl, i in zip(ax_top.get_xticklabels(), range(len(listH3))):
    lbl.set_color(highlight_h3[i])

# -----------------------------
# Legend
# -----------------------------
legend_handles = [
    Patch(facecolor='tab:blue', label='H3(\u03B1)'),
    Patch(facecolor='tab:orange', label='CENP-A(\u03B1)'),
]

ax.legend(handles=legend_handles, loc='upper right', fontsize=8)

plt.tight_layout()

plt.savefig('ASAT_EXIT_H3-CENPA_dna_gbsa_byres.pdf')
plt.savefig('ASAT_EXIT_H3-CENPA_dna_gbsa_byres.png')

plt.show()
