# %%
import pandas as pd
import re
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- tail_no_latch ---
filename1 = "ltH3core/run1/DNA+entrytail_no_latch/gbsa_ltH3core_1entry.txt"
filename2 = "ltH3core/run2/DNA+entrytail_no_latch/gbsa_ltH3core_2entry.txt"
filename3 = "ltH3core/run3/DNA+entrytail_no_latch/gbsa_ltH3core_3entry.txt"
filename4 = "ltH3core/run4/DNA+entrytail_no_latch/gbsa_ltH3core_4entry.txt"

f1 = "ltcenpacore/run1/DNA+entrytail_no_latch/gbsa_ltcenpacore_1entry.txt"
f2 = "ltcenpacore/run2/DNA+entrytail_no_latch/gbsa_ltcenpacore_2entry.txt"
f3 = "ltcenpacore/run3/DNA+entrytail_no_latch/gbsa_ltcenpacore_3entry.txt"
f4 = "ltcenpacore/run4/DNA+entrytail_no_latch/gbsa_ltcenpacore_4entry.txt"

# --- latch ---
filename1_l = "ltH3core/run1/DNA+entrylatch/gbsa_ltH3core_1entry.txt"
filename2_l = "ltH3core/run2/DNA+entrylatch/gbsa_ltH3core_2entry.txt"
filename3_l = "ltH3core/run3/DNA+entrylatch/gbsa_ltH3core_3entry.txt"
filename4_l = "ltH3core/run4/DNA+entrylatch/gbsa_ltH3core_4entry.txt"

f1_l = "ltcenpacore/run1/DNA+entrylatch/gbsa_ltcenpacore_1entry.txt"
f2_l = "ltcenpacore/run2/DNA+entrylatch/gbsa_ltcenpacore_2entry.txt"
f3_l = "ltcenpacore/run3/DNA+entrylatch/gbsa_ltcenpacore_3entry.txt"
f4_l = "ltcenpacore/run4/DNA+entrylatch/gbsa_ltcenpacore_4entry.txt"

# --- aN helix ---
filename1_a = "ltH3core/run1/DNA+entryaNhelix/gbsa_ltH3core_1entry.txt"
filename2_a = "ltH3core/run2/DNA+entryaNhelix/gbsa_ltH3core_2entry.txt"
filename3_a = "ltH3core/run3/DNA+entryaNhelix/gbsa_ltH3core_3entry.txt"
filename4_a = "ltH3core/run4/DNA+entryaNhelix/gbsa_ltH3core_4entry.txt"

f1_a = "ltcenpacore/run1/DNA+entryaNhelix/gbsa_ltcenpacore_1entry.txt"
f2_a = "ltcenpacore/run2/DNA+entryaNhelix/gbsa_ltcenpacore_2entry.txt"
f3_a = "ltcenpacore/run3/DNA+entryaNhelix/gbsa_ltcenpacore_3entry.txt"
f4_a = "ltcenpacore/run4/DNA+entryaNhelix/gbsa_ltcenpacore_4entry.txt"


# Pattern: match any line that has 6 columns with "value +/- error"
value_pattern = re.compile(r"([-\d.Ee]+)\s+\+/-\s+([-\d.Ee]+)")

data1, data2, data3, data4 = [], [], [], []
d1, d2, d3, d4 = [], [], [] ,[]

data1_l, data2_l, data3_l, data4_l = [], [], [], []
d1_l, d2_l, d3_l, d4_l = [], [], [], []

data1_a, data2_a, data3_a, data4_a = [], [], [], []
d1_a, d2_a, d3_a, d4_a = [], [], [], []

failures = []

with open(filename1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

# Define column headers
columns = [
    "Residue",
    "Internal", "Internal_err",
    "VDW", "VDW_err",
    "Electrostatic", "Electrostatic_err",
    "Polar", "Polar_err",
    "NonPolar", "NonPolar_err",
    "Total", "Total_err"
]

df1 = pd.DataFrame(data1, columns=columns)
df2 = pd.DataFrame(data2, columns=columns)
df3 = pd.DataFrame(data3, columns=columns)
df4 = pd.DataFrame(data4, columns=columns)

df5 = pd.DataFrame(d1, columns=columns)
df6 = pd.DataFrame(d2, columns=columns)
df7 = pd.DataFrame(d3, columns=columns)
df8 = pd.DataFrame(d4, columns=columns)

df1_l = pd.DataFrame(data1_l, columns=columns)
df2_l = pd.DataFrame(data2_l, columns=columns)
df3_l = pd.DataFrame(data3_l, columns=columns)
df4_l = pd.DataFrame(data4_l, columns=columns)

df5_l = pd.DataFrame(d1_l, columns=columns)
df6_l = pd.DataFrame(d2_l, columns=columns)
df7_l = pd.DataFrame(d3_l, columns=columns)
df8_l = pd.DataFrame(d4_l, columns=columns)

df1_a = pd.DataFrame(data1_a, columns=columns)
df2_a = pd.DataFrame(data2_a, columns=columns)
df3_a = pd.DataFrame(data3_a, columns=columns)
df4_a = pd.DataFrame(data4_a, columns=columns)

df5_a = pd.DataFrame(d1_a, columns=columns)
df6_a = pd.DataFrame(d2_a, columns=columns)
df7_a = pd.DataFrame(d3_a, columns=columns)
df8_a = pd.DataFrame(d4_a, columns=columns)

# ✅ Summary
print(f"✅ Parsed {len(df1)} residues.")
print(df1.head())

# Optional debug
if failures:
    print(f"\n⚠️ Skipped {len(failures)} lines. First 5:")
    for f in failures[:5]:
        print(f)
# Out:
# ✅ Parsed 329 residues.
#   Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0    DA51       0.0           0.0 -4.334    2.823        -38.996
# 1     DT2       0.0           0.0 -3.205    1.806       -128.717
# 2     DC3       0.0           0.0 -3.815    1.881       -147.675
# 3     DG4       0.0           0.0 -2.279    1.608       -136.386
# 4     DA5       0.0           0.0 -2.166    1.626       -135.578
#
#    Electrostatic_err    Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0              6.794   39.278      6.607    -0.533         0.355 -4.584
# 1             26.472  126.340     24.235    -0.456         0.306 -6.037
# 2             25.267  145.759     23.412    -0.601         0.326 -6.332
# 3             24.979  135.309     23.690    -0.466         0.282 -3.823
# 4             23.698  134.703     22.501    -0.367         0.241 -3.408
#
#    Total_err
# 0      3.307
# 1      4.069
# 2      3.973
# 3      2.961
# 4      2.895
#
# ⚠️ Skipped 72 lines. First 5:
# Wrong # of value/error pairs: | Run on Sun Jan 18 06:45:13 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2
# Wrong # of value/error pairs: Residue |  Location |       Internal      |    van der Waals    |    Electrostatic    |   Polar Solvation   |    Non-Polar Solv.  |       TOTAL
# Wrong # of value/error pairs: | Run on Sun Jan 18 09:10:00 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2

# %%
df6
# Out:
#     Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0      DA51       0.0           0.0 -0.007    0.005        -17.605
# 1       DT2       0.0           0.0 -0.008    0.005        -59.505
# 2       DC3       0.0           0.0 -0.017    0.019        -66.764
# 3       DG4       0.0           0.0 -0.188    0.432        -70.123
# 4       DA5       0.0           0.0 -0.477    0.730        -94.243
# ..      ...       ...           ...    ...      ...            ...
# 325  THR326       0.0           0.0 -0.306    0.745         -0.589
# 326  GLY327       0.0           0.0 -0.246    0.469         -5.068
# 327  GLY328       0.0           0.0 -0.289    0.504         -1.888
# 328  VAL329       0.0           0.0 -0.531    0.807         -4.258
# 329  LYS330       0.0           0.0 -0.357    0.455       -879.831
#
#      Electrostatic_err    Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0                1.683   17.601      1.682     0.000         0.000 -0.011
# 1                5.454   59.468      5.445     0.000         0.000 -0.045
# 2                8.273   66.691      8.247    -0.000         0.001 -0.090
# 3               11.712   70.074     11.609    -0.026         0.071 -0.263
# 4               20.567   94.032     20.443    -0.061         0.116 -0.749
# ..                 ...      ...        ...       ...           ...    ...
# 325              6.414    0.637      6.219    -0.031         0.082 -0.289
# 326              8.147    5.094      8.097    -0.042         0.091 -0.262
# 327              6.571    2.190      6.688    -0.055         0.111 -0.042
# 328              7.324    4.441      7.371    -0.100         0.183 -0.448
# 329             57.114  879.873     57.401    -0.092         0.149 -0.407
#
#      Total_err
# 0        0.006
# 1        0.014
# 2        0.048
# 3        0.735
# 4        1.076
# ..         ...
# 325      0.980
# 326      0.654
# 327      0.369
# 328      0.995
# 329      0.970
#
# [330 rows x 13 columns]

# %%
# Ensure each df has a numeric residue ID column
for df in [df1, df2, df3, df4]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs = []
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs.append(subset)

# Merge on Residue
merged = dfs[0]
for df in dfs[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   GLY295     5.28375              2.440119
# 1   PRO296    -1.44075              0.616470
# 2   ARG297    -2.32650              1.121491
# 3   ARG298    -2.58475              1.044667
# 4   ARG299    -1.18375              0.805344
# 5   SER300    -0.08900              0.363928
# 6   ARG301    -1.98125              0.836573
# 7   LYS302    -0.29350              0.893434
# 8   PRO303    -0.12250              0.187510
# 9   GLU304     1.30925              0.769457
# 10  ALA305     0.05075              0.189502
# 11  PRO306    -0.46125              0.415972
# 12  ARG307    -2.43075              1.091385
# 13  ARG308    -2.28250              1.033003
# 14  ARG309    -1.88775              1.021117
# 15  SER310    -0.66250              0.811040
# 16  PRO311    -0.32675              0.334638
# 17  SER312    -0.35375              0.708818
# 18  PRO313    -0.43925              0.479187
# 19  THR314    -0.09550              0.267944
# 20  PRO315    -0.61800              0.451873
# 21  THR316    -0.05275              0.254126
# 22  PRO317    -0.33125              0.434166
# 23  GLY318     0.02825              0.109948
# 24  PRO319    -0.28575              0.399153
# 25  SER320    -0.13700              0.442963
# 26  ARG321    -2.21100              1.062487
# 27  ARG322    -0.75400              0.502815
# 28  GLY323     0.10150              0.232357
# 29  PRO324    -0.72750              0.384558
# 30  SER325     0.08250              0.170906
# 31  LEU326    -0.57275              0.394448
# 32  GLY327     0.01400              0.108667
# 33  ALA328    -0.10425              0.177432
# 34  SER329    -0.03925              0.274141

# %%
# Ensure each df has a numeric residue ID column
for df in [df5, df6, df7, df8]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s = []
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s.append(subset)

# Merge on Residue
merged = df2s[0]
for df in df2s[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2 = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   ALA295     0.55350              1.059449
# 1   ARG296    -2.33750              1.028656
# 2   THR297    -1.14825              0.662864
# 3   LYS298     1.80350              1.625535
# 4   GLN299    -0.91225              0.523054
# 5   THR300    -1.14450              0.508741
# 6   ALA301    -0.61150              0.211844
# 7   ARG302    -2.51375              1.103082
# 8   LYS303     0.80025              1.674250
# 9   SER304    -0.94275              0.594630
# 10  THR305    -0.87475              0.779465
# 11  GLY306    -0.17700              0.240091
# 12  GLY307    -0.05050              0.166916
# 13  LYS308    -0.02150              0.866167
# 14  ALA309    -0.16075              0.219593
# 15  PRO310    -0.24575              0.294969
# 16  ARG311    -1.66075              0.932358
# 17  LYS312    -0.12775              1.184249
# 18  GLN313    -0.17525              0.365628
# 19  LEU314    -0.43650              0.632524
# 20  ALA315    -0.19925              0.313039
# 21  THR316    -0.28525              0.578079
# 22  LYS317    -0.21925              0.672427
# 23  ALA318    -0.14650              0.219841
# 24  ALA319    -0.08000              0.227010
# 25  ARG320    -1.32825              0.841731
# 26  LYS321    -0.64900              0.882346
# 27  SER322    -0.60675              0.660735
# 28  ALA323    -0.17600              0.307752
# 29  PRO324    -0.25425              0.298125
# 30  ALA325    -0.17275              0.255723
# 31  THR326    -0.39625              0.562559
# 32  GLY327    -0.23575              0.318084
# 33  GLY328    -0.16175              0.266019
# 34  VAL329    -0.18475              0.346496
# 35  LYS330     0.93875              1.252945

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_l, df2_l, df3_l, df4_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_l = []
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_l.append(subset)

# Merge on Residue
merged = dfs_l[0]
for df in dfs_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  HIE295     0.20875              0.250286
# 1  GLN296    -0.04400              0.317660
# 2  HIE297    -0.45075              0.549894
# 3  SER298    -0.08925              0.435802
# 4  ARG299    -2.91350              0.863841
# 5  ARG300    -2.11050              0.987142
# 6  ARG301    -4.59350              1.024515

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_l, df6_l, df7_l, df8_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_l = []
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_l.append(subset)

# Merge on Residue
merged = df2s_l[0]
for df in df2s_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  PRO295    -0.47450              0.290186
# 1  HIE296    -0.44950              0.455864
# 2  ARG297    -3.61975              1.114151
# 3  TYR298    -0.56050              0.446549
# 4  ARG299    -1.50075              0.755414
# 5  PRO300    -0.57400              0.348109
# 6  GLY301    -0.08600              0.256714

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_a, df2_a, df3_a, df4_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_a = []
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_a.append(subset)

# Merge on Residue
merged = dfs_a[0]
for df in dfs_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  THR295    -2.62400              0.841346
# 1  VAL296    -2.04750              0.565273
# 2  ALA297    -0.50125              0.306855
# 3  LEU298    -0.16275              0.068460
# 4  ARG299    -2.76525              1.032273
# 5  GLU300     1.86525              0.125437
# 6  ILE301    -0.08850              0.014674
# 7  ARG302    -1.57400              0.526863
# 8  ARG303    -1.83850              0.512495
# 9  TYR304     0.05850              0.011785

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_a, df6_a, df7_a, df8_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_a = []
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_a.append(subset)

# Merge on Residue
merged = df2s_a[0]
for df in df2s_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  GLN295    -0.64900              0.593873
# 1  GLY296    -0.13250              0.213167
# 2  TRP297     0.01325              0.170527
# 3  LEU298    -0.06900              0.031276
# 4  LYS299    -0.29775              1.106830
# 5  GLU300     1.67475              0.194259
# 6  ILE301    -0.07325              0.021474
# 7  ARG302    -0.90300              0.268230
# 8  LYS303    -0.97875              0.208473
# 9  LEU304    -0.05325              0.006010

# %%
avg1 = np.concatenate([
    np.array(result['Total_mean']),
    np.array(result_l['Total_mean']),
    np.array(result_a['Total_mean'])
])

avg2 = np.concatenate([
    np.array(result2['Total_mean']),
    np.array(result2_l['Total_mean']),
    np.array(result2_a['Total_mean'])
])

std = np.concatenate([
    np.array(result['Total_err_propagated']),
    np.array(result_l['Total_err_propagated']),
    np.array(result_a['Total_err_propagated'])
])

std2 = np.concatenate([
    np.array(result2['Total_err_propagated']),
    np.array(result2_l['Total_err_propagated']),
    np.array(result2_a['Total_err_propagated'])
])

ste1 = std / sqrt(4)
ste2 = std2 / sqrt(4)

# %%
width = 0.25

listltH3core = ['G1', 'P2', 'R3', 'R4', 'R5', 'S6', 'R7', 'K8', 'P9', 'E10',
            'A11', 'P12', 'R13', 'R14', 'R15', 'S16', 'P17', 'S18', 'P19', 'T20',
            'P21', 'T22', 'P23', 'G24', 'P25', 'S26', 'R27', 'R28', 'G29', 'P30',
            'S31', 'L32', 'G33', 'A34', 'S35', 'S36', 'H37', 'Q38', 'H39', 'S40',
            'R41', 'R42', 'R43', 'T44', 'V45', 'A46', 'L47', 'R48', 'E49', 'I50',
            'R51', 'R52', 'Y53']

listltcenpacore = ['A1', 'R2', 'T3', 'K4', 'Q5', 'T6', 'A7', 'R8', 'K9', 'S10',
        'T11', 'G12', 'G13', 'K14', 'A15', 'P16', 'R17', 'K18', 'Q19', 'L20',
        'A21', 'T22', 'K23', 'A24', 'A25', 'R26', 'K27', 'S28', 'A29', 'P30',
        'A31', 'T32', 'G33', 'G34', 'V35', 'K36', 'K37', 'P38', 'H39', 'R40',
        'Y41', 'R42', 'P43', 'G44', 'Q45', 'G46', 'W47', 'L48', 'K49', 'E50',
        'I51', 'R52', 'K53', 'L54']

# %%
from matplotlib.patches import Patch
# -----------------------------
# Region-specific colors
# -----------------------------
highlight_lth3core = {}

# tails (0–35)
for i in range(0, 36):
    highlight_lth3core[i] = "tab:orange"

# latch (36–42)
for i in range(36, 43):
    highlight_lth3core[i] = "tab:orange"

# alphaN (43–53)
for i in range(43, 53):
    highlight_lth3core[i] = "tab:blue"


highlight_ltcenpacore = {}

# tails (0–36)
for i in range(0, 37):
    highlight_ltcenpacore[i] = "tab:blue"

# latch (37–43)
for i in range(37, 44):
    highlight_ltcenpacore[i] = "tab:blue"

# alphaN (44–53)
for i in range(44, 54):
    highlight_ltcenpacore[i] = "tab:orange"


# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(9, 3))
ax = plt.gca()

# lth3core bars
for i in range(len(avg1)):
    plt.bar(
        x_ltH3core[i],
        avg1[i],
        yerr=ste1[i],
        width=width,
        color=highlight_lth3core[i]
    )

# ltcenpacore bars
for i in range(len(avg2)):
    plt.bar(
        x_ltcenpacore[i] + width,
        avg2[i],
        yerr=ste2[i],
        width=width,
        color=highlight_ltcenpacore[i]
    )

# baseline
plt.axhline(y=0, color='black')

# separator lines
for xpos in [37.5, 44.5]:
    ax.axvline(x=xpos, linestyle=':', color='black', linewidth=1)

# limits/title
plt.ylim(-5, 10)
plt.title('Entry Tail - DNA Binding Energy')
plt.ylabel('Binding Energy (kcal/mol)')

# -----------------------------
# Bottom axis (ltcenpacore)
# -----------------------------
ax.set_xticks(x_ltcenpacore + width/2)
ax.set_xticklabels(listltcenpacore, rotation=90)

for lbl, i in zip(ax.get_xticklabels(), range(len(listltcenpacore))):
    lbl.set_color(highlight_ltcenpacore[i])

# -----------------------------
# Top axis (lth3core)
# -----------------------------
ax_top = ax.twiny()

xmin = 0.5
xmax = 54.5 + width

ax.set_xlim(xmin, xmax)
ax_top.set_xlim(xmin, xmax)

ax_top.set_xticks(x_ltH3core)
ax_top.set_xticklabels(listltH3core, rotation=90)

for lbl, i in zip(ax_top.get_xticklabels(), range(len(listltH3core))):
    lbl.set_color(highlight_lth3core[i])

# -----------------------------
# Legend
# -----------------------------
legend_handles = [
    Patch(facecolor='tab:blue', label='H3'),
    Patch(facecolor='tab:orange', label='CENP-A'),
]

ax.legend(handles=legend_handles, loc='upper right', fontsize=8)

plt.tight_layout()

plt.savefig('WIDOM_ENTRY_ltH3core-ltcenpacore_dna_gbsa_byres.pdf')
plt.savefig('WIDOM_ENTRY_ltH3core-ltcenpacore_dna_gbsa_byres.png')

plt.show()
