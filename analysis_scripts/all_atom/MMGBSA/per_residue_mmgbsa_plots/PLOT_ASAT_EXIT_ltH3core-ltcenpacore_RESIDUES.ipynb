# %%
import pandas as pd
import re
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- tail_no_latch ---
filename1 = "CSltH3core/run1/DNA+exittail_no_latch/gbsa_CSltH3core_1exit.txt"
filename2 = "CSltH3core/run2/DNA+exittail_no_latch/gbsa_CSltH3core_2exit.txt"
filename3 = "CSltH3core/run3/DNA+exittail_no_latch/gbsa_CSltH3core_3exit.txt"
filename4 = "CSltH3core/run4/DNA+exittail_no_latch/gbsa_CSltH3core_4exit.txt"

f1 = "CSltcenpacore/run1/DNA+exittail_no_latch/gbsa_CSltcenpacore_1exit.txt"
f2 = "CSltcenpacore/run2/DNA+exittail_no_latch/gbsa_CSltcenpacore_2exit.txt"
f3 = "CSltcenpacore/run3/DNA+exittail_no_latch/gbsa_CSltcenpacore_3exit.txt"
f4 = "CSltcenpacore/run4/DNA+exittail_no_latch/gbsa_CSltcenpacore_4exit.txt"

# --- latch ---
filename1_l = "CSltH3core/run1/DNA+exitlatch/gbsa_CSltH3core_1exit.txt"
filename2_l = "CSltH3core/run2/DNA+exitlatch/gbsa_CSltH3core_2exit.txt"
filename3_l = "CSltH3core/run3/DNA+exitlatch/gbsa_CSltH3core_3exit.txt"
filename4_l = "CSltH3core/run4/DNA+exitlatch/gbsa_CSltH3core_4exit.txt"

f1_l = "CSltcenpacore/run1/DNA+exitlatch/gbsa_CSltcenpacore_1exit.txt"
f2_l = "CSltcenpacore/run2/DNA+exitlatch/gbsa_CSltcenpacore_2exit.txt"
f3_l = "CSltcenpacore/run3/DNA+exitlatch/gbsa_CSltcenpacore_3exit.txt"
f4_l = "CSltcenpacore/run4/DNA+exitlatch/gbsa_CSltcenpacore_4exit.txt"

# --- aN helix ---
filename1_a = "CSltH3core/run1/DNA+exitaNhelix/gbsa_CSltH3core_1exit.txt"
filename2_a = "CSltH3core/run2/DNA+exitaNhelix/gbsa_CSltH3core_2exit.txt"
filename3_a = "CSltH3core/run3/DNA+exitaNhelix/gbsa_CSltH3core_3exit.txt"
filename4_a = "CSltH3core/run4/DNA+exitaNhelix/gbsa_CSltH3core_4exit.txt"

f1_a = "CSltcenpacore/run1/DNA+exitaNhelix/gbsa_CSltcenpacore_1exit.txt"
f2_a = "CSltcenpacore/run2/DNA+exitaNhelix/gbsa_CSltcenpacore_2exit.txt"
f3_a = "CSltcenpacore/run3/DNA+exitaNhelix/gbsa_CSltcenpacore_3exit.txt"
f4_a = "CSltcenpacore/run4/DNA+exitaNhelix/gbsa_CSltcenpacore_4exit.txt"


# Pattern: match any line that has 6 columns with "value +/- error"
value_pattern = re.compile(r"([-\d.Ee]+)\s+\+/-\s+([-\d.Ee]+)")

data1, data2, data3, data4 = [], [], [], []
d1, d2, d3, d4 = [], [], [] ,[]

data1_l, data2_l, data3_l, data4_l = [], [], [], []
d1_l, d2_l, d3_l, d4_l = [], [], [], []

data1_a, data2_a, data3_a, data4_a = [], [], [], []
d1_a, d2_a, d3_a, d4_a = [], [], [], []

failures = []

with open(filename1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

# Define column headers
columns = [
    "Residue",
    "Internal", "Internal_err",
    "VDW", "VDW_err",
    "Electrostatic", "Electrostatic_err",
    "Polar", "Polar_err",
    "NonPolar", "NonPolar_err",
    "Total", "Total_err"
]

df1 = pd.DataFrame(data1, columns=columns)
df2 = pd.DataFrame(data2, columns=columns)
df3 = pd.DataFrame(data3, columns=columns)
df4 = pd.DataFrame(data4, columns=columns)

df5 = pd.DataFrame(d1, columns=columns)
df6 = pd.DataFrame(d2, columns=columns)
df7 = pd.DataFrame(d3, columns=columns)
df8 = pd.DataFrame(d4, columns=columns)

df1_l = pd.DataFrame(data1_l, columns=columns)
df2_l = pd.DataFrame(data2_l, columns=columns)
df3_l = pd.DataFrame(data3_l, columns=columns)
df4_l = pd.DataFrame(data4_l, columns=columns)

df5_l = pd.DataFrame(d1_l, columns=columns)
df6_l = pd.DataFrame(d2_l, columns=columns)
df7_l = pd.DataFrame(d3_l, columns=columns)
df8_l = pd.DataFrame(d4_l, columns=columns)

df1_a = pd.DataFrame(data1_a, columns=columns)
df2_a = pd.DataFrame(data2_a, columns=columns)
df3_a = pd.DataFrame(data3_a, columns=columns)
df4_a = pd.DataFrame(data4_a, columns=columns)

df5_a = pd.DataFrame(d1_a, columns=columns)
df6_a = pd.DataFrame(d2_a, columns=columns)
df7_a = pd.DataFrame(d3_a, columns=columns)
df8_a = pd.DataFrame(d4_a, columns=columns)

# ✅ Summary
print(f"✅ Parsed {len(df1)} residues.")
print(df1.head())

# Optional debug
if failures:
    print(f"\n⚠️ Skipped {len(failures)} lines. First 5:")
    for f in failures[:5]:
        print(f)
# Out:
# ✅ Parsed 329 residues.
#   Residue  Internal  Internal_err  VDW  VDW_err  Electrostatic  \
# 0    DA51       0.0           0.0 -0.0      0.0         -8.388
# 1     DT2       0.0           0.0 -0.0      0.0        -26.579
# 2     DC3       0.0           0.0 -0.0      0.0        -25.616
# 3     DA4       0.0           0.0 -0.0      0.0        -25.546
# 4     DA5       0.0           0.0 -0.0      0.0        -26.328
#
#    Electrostatic_err   Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0              0.811   8.387      0.811       0.0           0.0 -0.001
# 1              2.398  26.577      2.397       0.0           0.0 -0.002
# 2              1.943  25.615      1.942       0.0           0.0 -0.001
# 3              1.739  25.545      1.739       0.0           0.0 -0.001
# 4              1.616  26.327      1.616       0.0           0.0 -0.002
#
#    Total_err
# 0      0.001
# 1      0.001
# 2      0.001
# 3      0.001
# 4      0.001
#
# ⚠️ Skipped 72 lines. First 5:
# Wrong # of value/error pairs: | Run on Sun Jan 18 19:28:44 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2
# Wrong # of value/error pairs: Residue |  Location |       Internal      |    van der Waals    |    Electrostatic    |   Polar Solvation   |    Non-Polar Solv.  |       TOTAL
# Wrong # of value/error pairs: | Run on Mon Jan 19 06:16:25 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2

# %%
df6
# Out:
#     Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0      DA51       0.0           0.0 -0.000    0.000         -7.146
# 1       DT2       0.0           0.0 -0.000    0.000        -22.345
# 2       DC3       0.0           0.0 -0.000    0.000        -21.518
# 3       DA4       0.0           0.0 -0.000    0.000        -21.486
# 4       DA5       0.0           0.0 -0.000    0.000        -21.963
# ..      ...       ...           ...    ...      ...            ...
# 325  THR326       0.0           0.0 -0.229    0.504          0.967
# 326  GLY327       0.0           0.0 -0.062    0.123          2.425
# 327  GLY328       0.0           0.0 -0.071    0.157          2.758
# 328  VAL329       0.0           0.0 -0.145    0.381          1.278
# 329  LYS330       0.0           0.0 -0.227    0.466       -883.038
#
#      Electrostatic_err    Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0                1.423    7.145      1.423     0.000         0.000 -0.000
# 1                4.000   22.345      4.000     0.000         0.000 -0.000
# 2                3.493   21.518      3.493     0.000         0.000 -0.000
# 3                3.215   21.486      3.215     0.000         0.000 -0.000
# 4                3.085   21.963      3.085     0.000         0.000 -0.000
# ..                 ...      ...        ...       ...           ...    ...
# 325              6.419   -0.833      6.268    -0.060         0.152 -0.155
# 326              5.839   -2.339      5.805    -0.005         0.023  0.018
# 327              6.282   -2.666      6.311    -0.015         0.048  0.007
# 328              5.299   -1.201      5.282    -0.025         0.094 -0.093
# 329             56.831  883.020     57.093    -0.068         0.158 -0.312
#
#      Total_err
# 0        0.001
# 1        0.001
# 2        0.001
# 3        0.001
# 4        0.001
# ..         ...
# 325      0.733
# 326      0.102
# 327      0.152
# 328      0.424
# 329      1.170
#
# [330 rows x 13 columns]

# %%
# Ensure each df has a numeric residue ID column
for df in [df1, df2, df3, df4]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs = []
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs.append(subset)

# Merge on Residue
merged = dfs[0]
for df in dfs[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   GLY295     1.00975              1.212041
# 1   PRO296    -1.26100              0.608595
# 2   ARG297    -2.44475              0.923088
# 3   ARG298    -1.63500              0.948782
# 4   ARG299    -1.92375              0.893567
# 5   SER300    -0.50250              0.544900
# 6   ARG301    -1.98750              0.923443
# 7   LYS302    -0.57925              0.994692
# 8   PRO303    -0.18775              0.183969
# 9   GLU304     0.89325              0.534150
# 10  ALA305    -0.05150              0.195675
# 11  PRO306    -0.08275              0.190249
# 12  ARG307    -0.97675              0.794060
# 13  ARG308    -1.34900              0.846608
# 14  ARG309    -2.79325              0.872627
# 15  SER310    -1.26575              0.817102
# 16  PRO311    -1.36575              0.503090
# 17  SER312    -0.07100              0.370064
# 18  PRO313    -0.27925              0.239064
# 19  THR314    -0.02400              0.273543
# 20  PRO315    -0.16450              0.227630
# 21  THR316    -0.04900              0.257385
# 22  PRO317    -0.07550              0.201416
# 23  GLY318    -0.10200              0.229461
# 24  PRO319    -0.54475              0.532728
# 25  SER320    -0.14350              0.392341
# 26  ARG321    -0.88200              0.613614
# 27  ARG322    -1.68800              0.777002
# 28  GLY323     0.08675              0.106937
# 29  PRO324    -0.58975              0.365521
# 30  SER325    -1.15475              0.848203
# 31  LEU326    -0.61200              0.487330
# 32  GLY327    -0.06150              0.196294
# 33  ALA328    -0.60025              0.392005
# 34  SER329    -0.17325              0.376981

# %%
# Ensure each df has a numeric residue ID column
for df in [df5, df6, df7, df8]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s = []
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s.append(subset)

# Merge on Residue
merged = df2s[0]
for df in df2s[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2 = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   ALA295     3.13925              2.541864
# 1   ARG296    -1.77150              0.931890
# 2   THR297    -0.58050              0.617446
# 3   LYS298     1.33725              1.197658
# 4   GLN299    -0.59850              0.539144
# 5   THR300    -1.58300              0.559184
# 6   ALA301    -1.10875              0.411085
# 7   ARG302    -2.61075              0.948964
# 8   LYS303    -1.72800              0.653248
# 9   SER304    -0.58025              0.642106
# 10  THR305    -1.02725              0.629774
# 11  GLY306    -0.45575              0.363186
# 12  GLY307    -0.11025              0.317108
# 13  LYS308     1.96150              1.916386
# 14  ALA309    -0.12800              0.300322
# 15  PRO310    -0.42075              0.375342
# 16  ARG311    -1.39325              0.775655
# 17  LYS312    -0.70550              0.845459
# 18  GLN313    -0.61175              0.566890
# 19  LEU314    -0.03700              0.130959
# 20  ALA315     0.00900              0.126824
# 21  THR316    -0.58675              0.634471
# 22  LYS317    -0.65950              0.749920
# 23  ALA318    -0.21950              0.331140
# 24  ALA319    -0.36600              0.406976
# 25  ARG320    -1.50075              0.867585
# 26  LYS321    -0.95825              1.316400
# 27  SER322    -1.53400              0.930453
# 28  ALA323    -0.05600              0.125747
# 29  PRO324    -0.14875              0.184383
# 30  ALA325    -0.11025              0.246346
# 31  THR326    -0.15825              0.396098
# 32  GLY327    -0.02750              0.139810
# 33  GLY328    -0.02475              0.128422
# 34  VAL329    -0.16750              0.336017
# 35  LYS330    -0.40900              0.725738

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_l, df2_l, df3_l, df4_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_l = []
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_l.append(subset)

# Merge on Residue
merged = dfs_l[0]
for df in dfs_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  HIE295     0.10400              0.280168
# 1  GLN296    -0.36275              0.524057
# 2  HIE297    -0.61650              0.552234
# 3  SER298    -1.25675              0.769312
# 4  ARG299    -2.94100              0.916703
# 5  ARG300    -2.25625              0.929439
# 6  ARG301    -1.95625              1.093411

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_l, df6_l, df7_l, df8_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_l = []
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_l.append(subset)

# Merge on Residue
merged = df2s_l[0]
for df in df2s_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  PRO295    -0.66750              0.558462
# 1  HIE296    -0.35125              0.545896
# 2  ARG297    -1.74575              0.915675
# 3  TYR298    -2.10500              0.773448
# 4  ARG299    -1.20050              0.902260
# 5  PRO300    -2.01900              0.441504
# 6  GLY301    -0.75850              0.451020

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_a, df2_a, df3_a, df4_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_a = []
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_a.append(subset)

# Merge on Residue
merged = dfs_a[0]
for df in dfs_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  THR295    -0.71425              0.701360
# 1  VAL296    -2.64825              0.628411
# 2  ALA297    -1.19225              0.392557
# 3  LEU298    -0.09325              0.038031
# 4  ARG299    -2.77675              0.798624
# 5  GLU300     1.84825              0.111804
# 6  ILE301    -0.09325              0.013670
# 7  ARG302    -1.52500              0.532397
# 8  ARG303    -1.37700              0.343262
# 9  TYR304     0.06200              0.014902

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_a, df6_a, df7_a, df8_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_a = []
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_a.append(subset)

# Merge on Residue
merged = df2s_a[0]
for df in df2s_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  GLN295    -0.45925              0.438266
# 1  GLY296    -0.07175              0.191579
# 2  TRP297    -0.21075              0.267602
# 3  LEU298    -0.23825              0.219177
# 4  LYS299    -0.17125              0.937291
# 5  GLU300     1.51900              0.167585
# 6  ILE301    -0.08450              0.024059
# 7  ARG302    -0.81150              0.178931
# 8  LYS303    -1.02575              0.291172
# 9  LEU304    -0.04725              0.005879

# %%
avg1 = np.concatenate([
    np.array(result['Total_mean']),
    np.array(result_l['Total_mean']),
    np.array(result_a['Total_mean'])
])

avg2 = np.concatenate([
    np.array(result2['Total_mean']),
    np.array(result2_l['Total_mean']),
    np.array(result2_a['Total_mean'])
])

std = np.concatenate([
    np.array(result['Total_err_propagated']),
    np.array(result_l['Total_err_propagated']),
    np.array(result_a['Total_err_propagated'])
])

std2 = np.concatenate([
    np.array(result2['Total_err_propagated']),
    np.array(result2_l['Total_err_propagated']),
    np.array(result2_a['Total_err_propagated'])
])

ste1 = std / sqrt(4)
ste2 = std2 / sqrt(4)

# %%
width = 0.25

listltH3core = ['G1', 'P2', 'R3', 'R4', 'R5', 'S6', 'R7', 'K8', 'P9', 'E10',
            'A11', 'P12', 'R13', 'R14', 'R15', 'S16', 'P17', 'S18', 'P19', 'T20',
            'P21', 'T22', 'P23', 'G24', 'P25', 'S26', 'R27', 'R28', 'G29', 'P30',
            'S31', 'L32', 'G33', 'A34', 'S35', 'S36', 'H37', 'Q38', 'H39', 'S40',
            'R41', 'R42', 'R43', 'T44', 'V45', 'A46', 'L47', 'R48', 'E49', 'I50',
            'R51', 'R52', 'Y53']

listltcenpacore = ['A1', 'R2', 'T3', 'K4', 'Q5', 'T6', 'A7', 'R8', 'K9', 'S10',
        'T11', 'G12', 'G13', 'K14', 'A15', 'P16', 'R17', 'K18', 'Q19', 'L20',
        'A21', 'T22', 'K23', 'A24', 'A25', 'R26', 'K27', 'S28', 'A29', 'P30',
        'A31', 'T32', 'G33', 'G34', 'V35', 'K36', 'K37', 'P38', 'H39', 'R40',
        'Y41', 'R42', 'P43', 'G44', 'Q45', 'G46', 'W47', 'L48', 'K49', 'E50',
        'I51', 'R52', 'K53', 'L54']

# %%
from matplotlib.patches import Patch
# -----------------------------
# Region-specific colors
# -----------------------------
highlight_lth3core = {}

# tails (0–35)
for i in range(0, 36):
    highlight_lth3core[i] = "tab:orange"

# latch (36–42)
for i in range(36, 43):
    highlight_lth3core[i] = "tab:orange"

# alphaN (43–53)
for i in range(43, 53):
    highlight_lth3core[i] = "tab:blue"


highlight_ltcenpacore = {}

# tails (0–36)
for i in range(0, 37):
    highlight_ltcenpacore[i] = "tab:blue"

# latch (37–43)
for i in range(37, 44):
    highlight_ltcenpacore[i] = "tab:blue"

# alphaN (44–53)
for i in range(44, 54):
    highlight_ltcenpacore[i] = "tab:orange"


# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(9, 3))
ax = plt.gca()

# CSlth3core bars
for i in range(len(avg1)):
    plt.bar(
        x_ltH3core[i],
        avg1[i],
        yerr=ste1[i],
        width=width,
        color=highlight_lth3core[i]
    )

# CSltcenpacore bars
for i in range(len(avg2)):
    plt.bar(
        x_ltcenpacore[i] + width,
        avg2[i],
        yerr=ste2[i],
        width=width,
        color=highlight_ltcenpacore[i]
    )

# baseline
plt.axhline(y=0, color='black')

# separator lines
for xpos in [37.5, 44.5]:
    ax.axvline(x=xpos, linestyle=':', color='black', linewidth=1)

# limits/title
plt.ylim(-5, 10)
plt.title('Exit Tail - DNA Binding Energy')
plt.ylabel('Binding Energy (kcal/mol)')

# -----------------------------
# Bottom axis (CSltcenpacore)
# -----------------------------
ax.set_xticks(x_ltcenpacore + width/2)
ax.set_xticklabels(listltcenpacore, rotation=90)

for lbl, i in zip(ax.get_xticklabels(), range(len(listltcenpacore))):
    lbl.set_color(highlight_ltcenpacore[i])

# -----------------------------
# Top axis (CSlth3core)
# -----------------------------
ax_top = ax.twiny()

xmin = 0.5
xmax = 54.5 + width

ax.set_xlim(xmin, xmax)
ax_top.set_xlim(xmin, xmax)

ax_top.set_xticks(x_ltH3core)
ax_top.set_xticklabels(listltH3core, rotation=90)

for lbl, i in zip(ax_top.get_xticklabels(), range(len(listltH3core))):
    lbl.set_color(highlight_lth3core[i])

# -----------------------------
# Legend
# -----------------------------
legend_handles = [
    Patch(facecolor='tab:blue', label='H3(\u03B1)'),
    Patch(facecolor='tab:orange', label='CENP-A(\u03B1)'),
]

ax.legend(handles=legend_handles, loc='upper right', fontsize=8)

plt.tight_layout()

plt.savefig('ASAT_EXIT_ltH3core-ltcenpacore_dna_gbsa_byres.pdf')
plt.savefig('ASAT_EXIT_ltH3core-ltcenpacore_dna_gbsa_byres.png')

plt.show()
