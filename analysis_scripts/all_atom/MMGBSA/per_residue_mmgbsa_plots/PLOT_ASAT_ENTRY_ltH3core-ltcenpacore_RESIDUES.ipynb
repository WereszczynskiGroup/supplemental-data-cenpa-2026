# %%
import pandas as pd
import re
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- tail_no_latch ---
filename1 = "CSltH3core/run1/DNA+entrytail_no_latch/gbsa_CSltH3core_1entry.txt"
filename2 = "CSltH3core/run2/DNA+entrytail_no_latch/gbsa_CSltH3core_2entry.txt"
filename3 = "CSltH3core/run3/DNA+entrytail_no_latch/gbsa_CSltH3core_3entry.txt"
filename4 = "CSltH3core/run4/DNA+entrytail_no_latch/gbsa_CSltH3core_4entry.txt"

f1 = "CSltcenpacore/run1/DNA+entrytail_no_latch/gbsa_CSltcenpacore_1entry.txt"
f2 = "CSltcenpacore/run2/DNA+entrytail_no_latch/gbsa_CSltcenpacore_2entry.txt"
f3 = "CSltcenpacore/run3/DNA+entrytail_no_latch/gbsa_CSltcenpacore_3entry.txt"
f4 = "CSltcenpacore/run4/DNA+entrytail_no_latch/gbsa_CSltcenpacore_4entry.txt"

# --- latch ---
filename1_l = "CSltH3core/run1/DNA+entrylatch/gbsa_CSltH3core_1entry.txt"
filename2_l = "CSltH3core/run2/DNA+entrylatch/gbsa_CSltH3core_2entry.txt"
filename3_l = "CSltH3core/run3/DNA+entrylatch/gbsa_CSltH3core_3entry.txt"
filename4_l = "CSltH3core/run4/DNA+entrylatch/gbsa_CSltH3core_4entry.txt"

f1_l = "CSltcenpacore/run1/DNA+entrylatch/gbsa_CSltcenpacore_1entry.txt"
f2_l = "CSltcenpacore/run2/DNA+entrylatch/gbsa_CSltcenpacore_2entry.txt"
f3_l = "CSltcenpacore/run3/DNA+entrylatch/gbsa_CSltcenpacore_3entry.txt"
f4_l = "CSltcenpacore/run4/DNA+entrylatch/gbsa_CSltcenpacore_4entry.txt"

# --- aN helix ---
filename1_a = "CSltH3core/run1/DNA+entryaNhelix/gbsa_CSltH3core_1entry.txt"
filename2_a = "CSltH3core/run2/DNA+entryaNhelix/gbsa_CSltH3core_2entry.txt"
filename3_a = "CSltH3core/run3/DNA+entryaNhelix/gbsa_CSltH3core_3entry.txt"
filename4_a = "CSltH3core/run4/DNA+entryaNhelix/gbsa_CSltH3core_4entry.txt"

f1_a = "CSltcenpacore/run1/DNA+entryaNhelix/gbsa_CSltcenpacore_1entry.txt"
f2_a = "CSltcenpacore/run2/DNA+entryaNhelix/gbsa_CSltcenpacore_2entry.txt"
f3_a = "CSltcenpacore/run3/DNA+entryaNhelix/gbsa_CSltcenpacore_3entry.txt"
f4_a = "CSltcenpacore/run4/DNA+entryaNhelix/gbsa_CSltcenpacore_4entry.txt"


# Pattern: match any line that has 6 columns with "value +/- error"
value_pattern = re.compile(r"([-\d.Ee]+)\s+\+/-\s+([-\d.Ee]+)")

data1, data2, data3, data4 = [], [], [], []
d1, d2, d3, d4 = [], [], [] ,[]

data1_l, data2_l, data3_l, data4_l = [], [], [], []
d1_l, d2_l, d3_l, d4_l = [], [], [], []

data1_a, data2_a, data3_a, data4_a = [], [], [], []
d1_a, d2_a, d3_a, d4_a = [], [], [], []

failures = []

with open(filename1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f1) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_l) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_l.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(filename4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    data4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")


with open(f1_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d1_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f2_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d2_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f3_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d3_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

with open(f4_a) as f:
    for line in f:
        if "|" in line:
            parts = line.split("|")
            residue = parts[0].strip().replace(" ", "")  # e.g. "VAL337" or "GLU1382"
            # Now try to extract the 6 value ± error pairs
            values = value_pattern.findall(line)
            if len(values) == 6:
                try:
                    flat_values = [float(v) for pair in values for v in pair]
                    d4_a.append([residue] + flat_values)
                except Exception as e:
                    failures.append(f"Parse error: {line.strip()}")
            else:
                failures.append(f"Wrong # of value/error pairs: {line.strip()}")

# Define column headers
columns = [
    "Residue",
    "Internal", "Internal_err",
    "VDW", "VDW_err",
    "Electrostatic", "Electrostatic_err",
    "Polar", "Polar_err",
    "NonPolar", "NonPolar_err",
    "Total", "Total_err"
]

df1 = pd.DataFrame(data1, columns=columns)
df2 = pd.DataFrame(data2, columns=columns)
df3 = pd.DataFrame(data3, columns=columns)
df4 = pd.DataFrame(data4, columns=columns)

df5 = pd.DataFrame(d1, columns=columns)
df6 = pd.DataFrame(d2, columns=columns)
df7 = pd.DataFrame(d3, columns=columns)
df8 = pd.DataFrame(d4, columns=columns)

df1_l = pd.DataFrame(data1_l, columns=columns)
df2_l = pd.DataFrame(data2_l, columns=columns)
df3_l = pd.DataFrame(data3_l, columns=columns)
df4_l = pd.DataFrame(data4_l, columns=columns)

df5_l = pd.DataFrame(d1_l, columns=columns)
df6_l = pd.DataFrame(d2_l, columns=columns)
df7_l = pd.DataFrame(d3_l, columns=columns)
df8_l = pd.DataFrame(d4_l, columns=columns)

df1_a = pd.DataFrame(data1_a, columns=columns)
df2_a = pd.DataFrame(data2_a, columns=columns)
df3_a = pd.DataFrame(data3_a, columns=columns)
df4_a = pd.DataFrame(data4_a, columns=columns)

df5_a = pd.DataFrame(d1_a, columns=columns)
df6_a = pd.DataFrame(d2_a, columns=columns)
df7_a = pd.DataFrame(d3_a, columns=columns)
df8_a = pd.DataFrame(d4_a, columns=columns)

# ✅ Summary
print(f"✅ Parsed {len(df1)} residues.")
print(df1.head())

# Optional debug
if failures:
    print(f"\n⚠️ Skipped {len(failures)} lines. First 5:")
    for f in failures[:5]:
        print(f)
# Out:
# ✅ Parsed 329 residues.
#   Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0    DA51       0.0           0.0 -0.997    1.264        -16.773
# 1     DT2       0.0           0.0 -0.119    0.121        -52.814
# 2     DC3       0.0           0.0 -0.034    0.020        -54.531
# 3     DA4       0.0           0.0 -0.027    0.010        -56.212
# 4     DA5       0.0           0.0 -0.024    0.008        -61.455
#
#    Electrostatic_err   Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0              2.309  16.923      2.409    -0.154         0.189 -1.002
# 1              4.405  52.843      4.426    -0.001         0.007 -0.091
# 2              3.924  54.460      3.904    -0.000         0.000 -0.104
# 3              3.729  56.151      3.716     0.000         0.000 -0.088
# 4              4.399  61.387      4.386     0.000         0.000 -0.092
#
#    Total_err
# 0      1.310
# 1      0.091
# 2      0.055
# 3      0.026
# 4      0.022
#
# ⚠️ Skipped 72 lines. First 5:
# Wrong # of value/error pairs: | Run on Sun Jan 18 18:23:32 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2
# Wrong # of value/error pairs: Residue |  Location |       Internal      |    van der Waals    |    Electrostatic    |   Polar Solvation   |    Non-Polar Solv.  |       TOTAL
# Wrong # of value/error pairs: | Run on Mon Jan 19 00:27:50 2026
# Wrong # of value/error pairs: || GB non-polar solvation energies calculated with gbsa=2

# %%
df6
# Out:
#     Residue  Internal  Internal_err    VDW  VDW_err  Electrostatic  \
# 0      DA51       0.0           0.0 -0.006    0.036        -13.683
# 1       DT2       0.0           0.0 -0.002    0.011        -41.013
# 2       DC3       0.0           0.0 -0.001    0.001        -37.848
# 3       DA4       0.0           0.0 -0.001    0.001        -37.131
# 4       DA5       0.0           0.0 -0.000    0.001        -37.723
# ..      ...       ...           ...    ...      ...            ...
# 325  THR326       0.0           0.0 -0.496    0.747         -2.767
# 326  GLY327       0.0           0.0 -0.352    0.512         -6.213
# 327  GLY328       0.0           0.0 -0.412    0.573         -4.532
# 328  VAL329       0.0           0.0 -0.969    1.063         -2.807
# 329  LYS330       0.0           0.0 -2.069    1.777       -959.245
#
#      Electrostatic_err    Polar  Polar_err  NonPolar  NonPolar_err  Total  \
# 0                4.471   13.681      4.472    -0.001         0.012 -0.008
# 1               11.701   41.001     11.691    -0.000         0.002 -0.014
# 2                9.415   37.839      9.407     0.000         0.000 -0.009
# 3                8.270   37.123      8.264     0.000         0.000 -0.008
# 4                7.701   37.716      7.696     0.000         0.000 -0.008
# ..                 ...      ...        ...       ...           ...    ...
# 325              8.684    2.686      8.174    -0.095         0.148 -0.673
# 326              6.721    6.341      6.636    -0.059         0.098 -0.283
# 327              7.482    4.732      7.355    -0.058         0.098 -0.270
# 328              7.262    2.981      6.916    -0.169         0.216 -0.963
# 329             97.913  963.739    100.691    -0.506         0.388  1.919
#
#      Total_err
# 0        0.033
# 1        0.016
# 2        0.009
# 3        0.007
# 4        0.007
# ..         ...
# 325      1.563
# 326      0.670
# 327      0.673
# 328      1.315
# 329      4.231
#
# [330 rows x 13 columns]

# %%
# Ensure each df has a numeric residue ID column
for df in [df1, df2, df3, df4]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs = []
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs.append(subset)

# Merge on Residue
merged = dfs[0]
for df in dfs[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1, df2, df3, df4], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 329)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   GLY295     1.27800              1.920620
# 1   PRO296    -0.85775              0.498730
# 2   ARG297    -1.24200              1.057520
# 3   ARG298    -1.43125              0.982754
# 4   ARG299    -1.60300              0.767609
# 5   SER300    -0.57650              0.457491
# 6   ARG301    -2.11975              0.861418
# 7   LYS302    -0.38650              0.464172
# 8   PRO303    -0.12125              0.134000
# 9   GLU304     1.53400              0.489835
# 10  ALA305     0.09500              0.173913
# 11  PRO306    -0.30875              0.274403
# 12  ARG307    -2.67100              0.750451
# 13  ARG308    -2.21000              0.506240
# 14  ARG309    -2.41625              0.728013
# 15  SER310    -1.71600              0.454753
# 16  PRO311    -0.78025              0.357906
# 17  SER312     0.25275              0.211464
# 18  PRO313    -0.90925              0.321311
# 19  THR314    -1.43650              0.473760
# 20  PRO315    -0.27600              0.260294
# 21  THR316     0.05600              0.158905
# 22  PRO317    -0.28025              0.307055
# 23  GLY318     0.03400              0.063929
# 24  PRO319    -0.21575              0.330148
# 25  SER320    -0.08425              0.374208
# 26  ARG321    -1.06925              0.651582
# 27  ARG322    -1.97800              0.955348
# 28  GLY323    -0.06650              0.201240
# 29  PRO324    -0.14125              0.240726
# 30  SER325     0.04150              0.226098
# 31  LEU326    -0.18925              0.284958
# 32  GLY327     0.00975              0.133448
# 33  ALA328    -0.09750              0.237411
# 34  SER329    -0.15600              0.552153

# %%
# Ensure each df has a numeric residue ID column
for df in [df5, df6, df7, df8]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s = []
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s.append(subset)

# Merge on Residue
merged = df2s[0]
for df in df2s[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5, df6, df7, df8], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 330)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2 = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2)
# Out:
#    Residue  Total_mean  Total_err_propagated
# 0   ALA295     1.40550              1.837995
# 1   ARG296    -2.09200              0.919152
# 2   THR297    -0.40000              0.703979
# 3   LYS298     0.50600              1.402426
# 4   GLN299    -0.10075              0.403697
# 5   THR300    -0.53125              0.591580
# 6   ALA301    -0.26050              0.279570
# 7   ARG302    -2.29325              0.743225
# 8   LYS303     4.16825              1.563491
# 9   SER304    -0.34025              0.695537
# 10  THR305    -0.75450              0.632517
# 11  GLY306    -0.54725              0.352258
# 12  GLY307    -0.68425              0.349799
# 13  LYS308    -0.43750              1.190338
# 14  ALA309    -0.15625              0.172545
# 15  PRO310    -0.01325              0.227924
# 16  ARG311    -0.74775              0.706441
# 17  LYS312    -0.86275              0.885130
# 18  GLN313    -0.71850              0.599602
# 19  LEU314    -0.61500              0.495160
# 20  ALA315    -0.22200              0.291781
# 21  THR316    -0.18250              0.478077
# 22  LYS317    -0.33500              0.700796
# 23  ALA318    -0.07375              0.194982
# 24  ALA319    -0.10750              0.239150
# 25  ARG320    -0.82525              0.698629
# 26  LYS321    -0.32850              0.716867
# 27  SER322    -0.34525              0.547106
# 28  ALA323    -0.11000              0.270034
# 29  PRO324    -0.35125              0.406525
# 30  ALA325    -0.13975              0.257650
# 31  THR326    -0.30900              0.500781
# 32  GLY327    -0.11300              0.209930
# 33  GLY328    -0.16300              0.267194
# 34  VAL329    -0.69625              0.541349
# 35  LYS330     0.40575              1.274340

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_l, df2_l, df3_l, df4_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_l = []
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_l.append(subset)

# Merge on Residue
merged = dfs_l[0]
for df in dfs_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_l, df2_l, df3_l, df4_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  HIE295     0.21075              0.223691
# 1  GLN296     0.11550              0.269941
# 2  HIE297     0.13425              0.258516
# 3  SER298    -0.77825              0.570780
# 4  ARG299    -4.32750              0.903474
# 5  ARG300    -2.24675              0.788156
# 6  ARG301    -3.40075              0.925236

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_l, df6_l, df7_l, df8_l]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_l = []
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_l.append(subset)

# Merge on Residue
merged = df2s_l[0]
for df in df2s_l[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_l, df6_l, df7_l, df8_l], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 301)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_l = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_l)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  PRO295    -0.12200              0.210819
# 1  HIE296    -0.82075              0.621472
# 2  ARG297    -1.92475              0.836204
# 3  TYR298    -0.74600              0.681792
# 4  ARG299    -1.59425              0.887924
# 5  PRO300    -0.49025              0.370025
# 6  GLY301     0.05400              0.155466

# %%
# Ensure each df has a numeric residue ID column
for df in [df1_a, df2_a, df3_a, df4_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
dfs_a = []
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    dfs_a.append(subset)

# Merge on Residue
merged = dfs_a[0]
for df in dfs_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df1_a, df2_a, df3_a, df4_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  THR295    -0.77400              0.628938
# 1  VAL296    -1.91575              0.425245
# 2  ALA297    -0.60250              0.273436
# 3  LEU298    -0.12225              0.034589
# 4  ARG299    -1.44550              1.118214
# 5  GLU300     1.85825              0.103193
# 6  ILE301    -0.09525              0.013274
# 7  ARG302    -1.43050              0.470355
# 8  ARG303    -1.71075              0.477821
# 9  TYR304     0.05800              0.011843

# %%
# Ensure each df has a numeric residue ID column
for df in [df5_a, df6_a, df7_a, df8_a]:
    df["ResID"] = df["Residue"].str.extract(r"(\d+)$").astype(int)

# Extract Total energy for residues 295–304 from each df
df2s_a = []
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset = subset[["Residue", "Total"]].rename(columns={"Total": f"Total_{i}"})
    df2s_a.append(subset)

# Merge on Residue
merged = df2s_a[0]
for df in df2s_a[1:]:
    merged = pd.merge(merged, df, on="Residue")

# Calculate mean and std across the 5 Total columns
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)
merged["Total_std"] = merged[[f"Total_{i}" for i in range(1, 5)]].std(axis=1)

# After merging the Total columns:

# Also merge Total_err columns from each df
for i, df in enumerate([df5_a, df6_a, df7_a, df8_a], start=1):
    subset_err = df[(df["ResID"] >= 295) & (df["ResID"] <= 304)].copy()
    subset_err = subset_err[["Residue", "Total_err"]].rename(columns={"Total_err": f"Total_err_{i}"})
    merged = pd.merge(merged, subset_err, on="Residue")

# Calculate mean of Total values (same as before)
merged["Total_mean"] = merged[[f"Total_{i}" for i in range(1, 5)]].mean(axis=1)

# Propagate the standard deviations of the Total_err columns
# Standard error of the mean = sqrt(sum of variances) / N
merged["Total_err_propagated"] = np.sqrt(
    np.sum(np.square(merged[[f"Total_err_{i}" for i in range(1, 5)]]), axis=1)
) / 4

# Final result with propagated error
result2_a = merged[["Residue", "Total_mean", "Total_err_propagated"]]

print(result2_a)
# Out:
#   Residue  Total_mean  Total_err_propagated
# 0  GLN295    -0.48500              0.489005
# 1  GLY296    -0.02425              0.066555
# 2  TRP297    -0.12475              0.302001
# 3  LEU298    -0.13225              0.104912
# 4  LYS299    -0.65950              0.764646
# 5  GLU300     1.74950              0.241301
# 6  ILE301    -0.07050              0.017188
# 7  ARG302    -0.74500              0.166663
# 8  LYS303    -0.89425              0.189619
# 9  LEU304    -0.05075              0.005953

# %%
avg1 = np.concatenate([
    np.array(result['Total_mean']),
    np.array(result_l['Total_mean']),
    np.array(result_a['Total_mean'])
])

avg2 = np.concatenate([
    np.array(result2['Total_mean']),
    np.array(result2_l['Total_mean']),
    np.array(result2_a['Total_mean'])
])

std = np.concatenate([
    np.array(result['Total_err_propagated']),
    np.array(result_l['Total_err_propagated']),
    np.array(result_a['Total_err_propagated'])
])

std2 = np.concatenate([
    np.array(result2['Total_err_propagated']),
    np.array(result2_l['Total_err_propagated']),
    np.array(result2_a['Total_err_propagated'])
])

ste1 = std / sqrt(4)
ste2 = std2 / sqrt(4)

# %%
width = 0.25

listltH3core = ['G1', 'P2', 'R3', 'R4', 'R5', 'S6', 'R7', 'K8', 'P9', 'E10',
            'A11', 'P12', 'R13', 'R14', 'R15', 'S16', 'P17', 'S18', 'P19', 'T20',
            'P21', 'T22', 'P23', 'G24', 'P25', 'S26', 'R27', 'R28', 'G29', 'P30',
            'S31', 'L32', 'G33', 'A34', 'S35', 'S36', 'H37', 'Q38', 'H39', 'S40',
            'R41', 'R42', 'R43', 'T44', 'V45', 'A46', 'L47', 'R48', 'E49', 'I50',
            'R51', 'R52', 'Y53']

listltcenpacore = ['A1', 'R2', 'T3', 'K4', 'Q5', 'T6', 'A7', 'R8', 'K9', 'S10',
        'T11', 'G12', 'G13', 'K14', 'A15', 'P16', 'R17', 'K18', 'Q19', 'L20',
        'A21', 'T22', 'K23', 'A24', 'A25', 'R26', 'K27', 'S28', 'A29', 'P30',
        'A31', 'T32', 'G33', 'G34', 'V35', 'K36', 'K37', 'P38', 'H39', 'R40',
        'Y41', 'R42', 'P43', 'G44', 'Q45', 'G46', 'W47', 'L48', 'K49', 'E50',
        'I51', 'R52', 'K53', 'L54']

# %%
from matplotlib.patches import Patch
# -----------------------------
# Region-specific colors
# -----------------------------
highlight_lth3core = {}

# tails (0–35)
for i in range(0, 36):
    highlight_lth3core[i] = "tab:orange"

# latch (36–42)
for i in range(36, 43):
    highlight_lth3core[i] = "tab:orange"

# alphaN (43–53)
for i in range(43, 53):
    highlight_lth3core[i] = "tab:blue"


highlight_ltcenpacore = {}

# tails (0–36)
for i in range(0, 37):
    highlight_ltcenpacore[i] = "tab:blue"

# latch (37–43)
for i in range(37, 44):
    highlight_ltcenpacore[i] = "tab:blue"

# alphaN (44–53)
for i in range(44, 54):
    highlight_ltcenpacore[i] = "tab:orange"


# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(9, 3))
ax = plt.gca()

# CSlth3core bars
for i in range(len(avg1)):
    plt.bar(
        x_ltH3core[i],
        avg1[i],
        yerr=ste1[i],
        width=width,
        color=highlight_lth3core[i]
    )

# CSltcenpacore bars
for i in range(len(avg2)):
    plt.bar(
        x_ltcenpacore[i] + width,
        avg2[i],
        yerr=ste2[i],
        width=width,
        color=highlight_ltcenpacore[i]
    )

# baseline
plt.axhline(y=0, color='black')

# separator lines
for xpos in [37.5, 44.5]:
    ax.axvline(x=xpos, linestyle=':', color='black', linewidth=1)

# limits/title
plt.ylim(-5, 10)
plt.title('Entry Tail - DNA Binding Energy')
plt.ylabel('Binding Energy (kcal/mol)')

# -----------------------------
# Bottom axis (CSltcenpacore)
# -----------------------------
ax.set_xticks(x_ltcenpacore + width/2)
ax.set_xticklabels(listltcenpacore, rotation=90)

for lbl, i in zip(ax.get_xticklabels(), range(len(listltcenpacore))):
    lbl.set_color(highlight_ltcenpacore[i])

# -----------------------------
# Top axis (CSlth3core)
# -----------------------------
ax_top = ax.twiny()

xmin = 0.5
xmax = 54.5 + width

ax.set_xlim(xmin, xmax)
ax_top.set_xlim(xmin, xmax)

ax_top.set_xticks(x_ltH3core)
ax_top.set_xticklabels(listltH3core, rotation=90)

for lbl, i in zip(ax_top.get_xticklabels(), range(len(listltH3core))):
    lbl.set_color(highlight_lth3core[i])

# -----------------------------
# Legend
# -----------------------------
legend_handles = [
    Patch(facecolor='tab:blue', label='H3(\u03B1)'),
    Patch(facecolor='tab:orange', label='CENP-A(\u03B1)'),
]

ax.legend(handles=legend_handles, loc='upper right', fontsize=8)

plt.tight_layout()

plt.savefig('ASAT_ENTRY_ltH3core-ltcenpacore_dna_gbsa_byres.pdf')
plt.savefig('ASAT_ENTRY_ltH3core-ltcenpacore_dna_gbsa_byres.png')

plt.show()
